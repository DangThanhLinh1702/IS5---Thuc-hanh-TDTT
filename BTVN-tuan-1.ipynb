# %%
line = input()
a, b, c = map(float, line.split())
if a**2 == b**2 + c**2:
    print(f'{(1/2)*b*c}')
elif b**2 == a**2 + c**2:
     print(f'{(1/2)*a*c}')
elif c**2 == a**2 + b**2:
     print(f'{(1/2)*a*b}')
else:
    print("Khong phai 3 canh cua tam giac")
# Out:
#  6 7 8
# Khong phai 3 canh cua tam giac

# %%
n = int(input())
print("So ban da nhap la", n)
print(2*n)
# Out:
# So ban da nhap la 5
# 10

# %%
a = float(input("Nhap chieu rong"))
b = float(input("Nhap chieu dai"))
s = a*b - (a/2)**2*3.14
print("Dien tich manh dat can tim la: ",f'{s:.2f}')
# Out:
# Dien tich manh dat can tim la:  8792.96

# %%
 s = input("Nhap chuoi gom cac ki tu do dai >= 20:")
if len(s) >= 20:
    print(s[4], s[8])
else:
    print("Chua du so ki tu")
# Out:
# Nhap chuoi gom cac ki tu do dai >= 20: týufhiohfafghjhghjkajhdjkslf
# h f

# %%
n = input("Nhap chu cai")
if n.islower() :
    print(n.upper())
elif n.isupper() :
    print(n.lower())
else:
    print("Day khong phai la chu cai")
# Out:
# J

# %%
#8
name = input("Ten chu ho")
t = chi_so_thang_truoc = int(input("Chi so thang truoc"))
s = chi_so_thang_sau = int(input("Chi so thang sau")) #Nhập thông tin
print("Ten chu ho: ", name)
m = money = s - t #công thức

if 0<=m<=50:
    print("Tien phai tra la:", m*1984*1.08)
elif 51<=m<=100:
    print("Tien phai tra la:", m*2050*1.08)
elif 101<=m<=200:
    print("Tien phai tra la:", m*2380*1.08)
elif 201<=m<=300:
    print("Tien phai tra la:", m*2998*1.08)
elif 301<=m<=400:
    print("Tien phai tra la:", m*3350*1.08)
elif m>=401 :
    print("Tien phai tra la:", m*3460*1.08)
else:
    print("Khong hop le")
# Out:
# Ten chu ho Pham Xuan Toai
# Chi so thang truoc 1020
# Chi so thang sau 1070
# Ten chu ho:  Pham Xuan Toai
# Tien phai tra la: 107136.0

# %%
#B1
a = int(input())
if a % 2 == 0: 
    print("This is even number")
else:
    print("This is odd number")
# Out:
#  5
# This is odd number

# %%
#B2
a = int(input())
if a %10 == 5:
    print("True")
else :
    print("False")
# Out:
#  10
# False

# %%
#B3
a = int(input())
if a % 15 == 0:
    print("True")
else :
    print("False")
# Out:
#  31
# False

# %%
#B5:
line = input()
a, b = map(int, line.split())
if a > b:
    print(a)
elif b > a :
    print(b) 

else :
    print("Hai so da cho bang nhau")
# Out:
#  5 6
# 6

# %%
#B6
a = input()
if a.isalpha() :
    print("Day la chu cai")
if a.isdigit() :
    print("Day la chu so")
# Out:
#  5
# Day la chu so

# %%
#B7
a = float(input())
0 <= a <= 10
if a >= 8:
    print("Gioi")
elif 6.5 <= a <= 8:
    print("Kha")
elif 5 <= a <= 6.5:
    print("Trung binh")
else:
    print("Yeu")
# Out:
#  4
# Yeu

# %%
#B8
a = int(input())
if a % 400 == 0 or (a & 4 == 0 and a %100 != 0):
    print("Day la nam nhuan")
else:
    print("Day khong phai nam nhuan")
# Out:
#  2024
# Day la nam nhuan

# %%
#B9
n = int(input())
match n :
    case 1:
        print("Mot")
    case 2:
        print("Hai")
    case 3:
        print("Ba")
    case 4:
        print("Bon")
    case 5:
        print("Nam")
    case 6:
        print("Sau")
    case 7:
        print("Bay")
    case 8:
        print("Tam")
    case 9:
        print("Chin")
# Out:
#  5
# Nam

# %%
#B10
n =int(input())
0<= n <= 10
if n >= 4:
    print("Qua mon")
else: 
    print("Hoc lai")
# Out:
#  10
# Qua mon

# %%
n = int(input())
m = 2025 - n
print("Tuoi cua ban la:", m)
# Out:
#  2
# Tuoi cua ban la: 2023

# %%
n = input()
if n.isdigit():
    print("Day la chu so")
elif n.isalpha():
    print("Day la chu cai")
else :
    print("Day khong phai chu so hay chu cai")
# Out:
# Day khong phai chu so hay chu cai

# %%
n = str(input("Moi nhap chu cai"))
print(chr(ord(n)+31))
# Out:
# l

# %%
n = input()
if n.isalpha():
    print("Day la chu cai")
else:
    print("Day khong phai chu cai")
# Out:
# Day khong phai chu cai
